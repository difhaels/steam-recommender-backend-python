# %%
import json

# %%
# Load JSON
with open("dataset_from_500.json", "r", encoding="utf-8") as f:
    raw = json.load(f)

# %%
# =========================
# 1. Hitung jumlah user
# =========================
total_users = len(raw["data"])

print(f"Total user: {total_users}")
# Out:
# Total user: 500
